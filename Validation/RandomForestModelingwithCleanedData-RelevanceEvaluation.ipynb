# %% [markdown]
# # Modeling with Random Forest Classifer

# %% [markdown]
# #### We build multiple Random Forest Classifer Models to Train on cleaned text and variables:
# #### Relevancy_score (highly relevant (4), very relevant (3), relevant (2), minimally relevant (1), not relevant (0))
# #### Treatment_Number (user receives treatment (1), user does not receive treatment (0))
# #### Recommendation_Score (user recommends treatment (1), user does not recommend treatment (0))

# %%
#import the necessary library, modules, functions, settings 
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
from seaborn import set_style
set_style("whitegrid")
import seaborn as sns

# %%
#load in the csv file containing the relevance validation set as a data frame 
data_df = pd.read_csv("FinalEvaluatedRelevanceValidation.csv")

# %%
#import the necessary library, modules, functions, settings 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,  classification_report
from sklearn.model_selection import train_test_split

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=100, shuffle = True, test_size=0.2)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=100)
clf.fit(X_train_vect, y1_train)
# Out:
# RandomForestClassifier(random_state=100)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.7959183673469388
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87        50
#            1       0.00      0.00      0.00        13
#            2       0.85      0.91      0.88        32
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.80        98
#    macro avg       0.33      0.38      0.35        98
# weighted avg       0.68      0.80      0.73        98
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=200, shuffle = True, test_size=0.2,stratify=y2)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=200)
clf.fit(X_train_vect, y2_train)
# Out:
# RandomForestClassifier(random_state=200)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y2_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.8163265306122449
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81        50
#            1       0.78      0.88      0.82        48
#
#     accuracy                           0.82        98
#    macro avg       0.82      0.82      0.82        98
# weighted avg       0.82      0.82      0.82        98

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=300, shuffle = True, test_size=0.2,stratify=y3)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=300)
clf.fit(X_train_vect, y3_train)
# Out:
# RandomForestClassifier(random_state=300)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.8469387755102041
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        83
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.85        98
#    macro avg       0.42      0.50      0.46        98
# weighted avg       0.72      0.85      0.78        98
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=400, shuffle = True, test_size=0.2)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=400)
clf.fit(X_train_vect, y1_train)
# Out:
# RandomForestClassifier(random_state=400)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.6836734693877551
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79        50
#            1       0.00      0.00      0.00        18
#            2       0.66      0.81      0.72        26
#            3       0.00      0.00      0.00         4
#
#     accuracy                           0.68        98
#    macro avg       0.34      0.43      0.38        98
# weighted avg       0.53      0.68      0.60        98
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=500, shuffle = True, test_size=0.2,stratify=y2)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=500)
clf.fit(X_train_vect, y2_train)
# Out:
# RandomForestClassifier(random_state=500)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y2_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.826530612244898
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83        50
#            1       0.82      0.83      0.82        48
#
#     accuracy                           0.83        98
#    macro avg       0.83      0.83      0.83        98
# weighted avg       0.83      0.83      0.83        98

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=600, shuffle = True, test_size=0.2, stratify=y3)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=600)
clf.fit(X_train_vect, y3_train)
# Out:
# RandomForestClassifier(random_state=600)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.8469387755102041
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        83
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.85        98
#    macro avg       0.42      0.50      0.46        98
# weighted avg       0.72      0.85      0.78        98
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
