# %% [markdown]
# # Modeling with SVM Classifer

# %% [markdown]
# #### We build multiple SVM Classifer Models to Train on cleaned text and variables:
# #### Relevancy_score (highly relevant (4), very relevant (3), relevant (2), minimally relevant (1), not relevant (0))
# #### Treatment_Number (user receives treatment (1), user does not receive treatment (0))
# #### Recommendation_Score (user recommends treatment (1), user does not recommend treatment (0))

# %%
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
from seaborn import set_style
set_style("whitegrid")
import seaborn as sns

# %%
data_df = pd.read_csv("enumerated_test_comments.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,  classification_report
from sklearn.model_selection import train_test_split

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
feature_names = vectorizer1.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=100, test_size=0.2, stratify=y1)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=100)
clf.fit(X_train_vect, y1_train)
# Out:
# SVC(kernel='linear', random_state=100)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.8288288288288288
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            2       0.86      0.94      0.90        83
#            3       0.72      0.52      0.60        25
#            4       0.50      0.33      0.40         3
#
#     accuracy                           0.83       111
#    macro avg       0.69      0.60      0.63       111
# weighted avg       0.82      0.83      0.82       111

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
feature_names = vectorizer1.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=200, test_size=0.2, stratify=y2)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=200)
clf.fit(X_train_vect, y2_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 3
#       1 # Initialize and train an SVM classifier
#       2 clf = SVC(kernel='linear', random_state=200)
# ----> 3 clf.fit(X_train_vect, y2_train)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:743, in BaseSVC._validate_targets(self, y)
#     741 self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#     742 if len(cls) < 2:
# --> 743     raise ValueError(
#     744         "The number of classes has to be greater than one; got %d class"
#     745         % len(cls)
#     746     )
#     748 self.classes_ = cls
#     750 return np.asarray(y, dtype=np.float64, order="C")
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y2_pred = clf.predict(X_test_vect)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 3
#       1 # Make predictions
#       2 X_test_vect = vectorizer1.transform(X_test)
# ----> 3 y2_pred = clf.predict(X_test_vect)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:636, in BaseLibSVM._validate_for_predict(self, X)
#     629         raise ValueError(
#     630             "X.shape[1] = %d should be equal to %d, "
#     631             "the number of samples at training time"
#     632             % (X.shape[1], self.shape_fit_[0])
#     633         )
#     634 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     635 # Check that _n_support is consistent with support_vectors
# --> 636 sv = self.support_vectors_
#     637 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     638     raise ValueError(
#     639         f"The internal representation of {self.__class__.__name__} was altered"
#     640     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 # Evaluate the model
# ----> 2 print("Accuracy:", accuracy_score(y2_test, y2_pred))
#       3 print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
#
# NameError: name 'y2_pred' is not defined

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 #Produce the confusion matrix
# ----> 2 cm = confusion_matrix(y2_test, y2_pred)
#       3 plt.figure(figsize=(8, 6))
#       4 sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
#
# NameError: name 'y2_pred' is not defined

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
feature_names = vectorizer1.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=300, test_size=0.2,stratify=y3)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=300)
clf.fit(X_train_vect, y3_train)
# Out:
# SVC(kernel='linear', random_state=300)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.7747747747747747
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        74
#            1       0.70      0.57      0.63        37
#
#     accuracy                           0.77       111
#    macro avg       0.75      0.72      0.73       111
# weighted avg       0.77      0.77      0.77       111

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
feature_names = vectorizer2.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=400, test_size=0.2,stratify=y1)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=400)
clf.fit(X_train_vect, y1_train)
# Out:
# SVC(kernel='linear', random_state=400)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.8198198198198198
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            2       0.83      0.98      0.90        83
#            3       0.77      0.40      0.53        25
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.82       111
#    macro avg       0.53      0.46      0.47       111
# weighted avg       0.79      0.82      0.79       111
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
feature_names = vectorizer2.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=500, test_size=0.2,stratify=y2)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=500)
clf.fit(X_train_vect, y2_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 3
#       1 # Initialize and train an SVM classifier
#       2 clf = SVC(kernel='linear', random_state=500)
# ----> 3 clf.fit(X_train_vect, y2_train)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:743, in BaseSVC._validate_targets(self, y)
#     741 self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#     742 if len(cls) < 2:
# --> 743     raise ValueError(
#     744         "The number of classes has to be greater than one; got %d class"
#     745         % len(cls)
#     746     )
#     748 self.classes_ = cls
#     750 return np.asarray(y, dtype=np.float64, order="C")
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y2_pred = clf.predict(X_test_vect)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 3
#       1 # Make predictions
#       2 X_test_vect = vectorizer2.transform(X_test)
# ----> 3 y2_pred = clf.predict(X_test_vect)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/svm/_base.py:636, in BaseLibSVM._validate_for_predict(self, X)
#     629         raise ValueError(
#     630             "X.shape[1] = %d should be equal to %d, "
#     631             "the number of samples at training time"
#     632             % (X.shape[1], self.shape_fit_[0])
#     633         )
#     634 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     635 # Check that _n_support is consistent with support_vectors
# --> 636 sv = self.support_vectors_
#     637 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     638     raise ValueError(
#     639         f"The internal representation of {self.__class__.__name__} was altered"
#     640     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 2
#       1 # Evaluate the model
# ----> 2 print("Accuracy:", accuracy_score(y2_test, y2_pred))
#       3 print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
#
# NameError: name 'y2_pred' is not defined

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 2
#       1 #Produce the confusion matrix
# ----> 2 cm = confusion_matrix(y2_test, y2_pred)
#       3 plt.figure(figsize=(8, 6))
#       4 sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
#
# NameError: name 'y2_pred' is not defined

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
feature_names = vectorizer2.get_feature_names_out()
X_array = vectors.toarray()
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=600, test_size=0.2,stratify=y3)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
# Initialize and train an SVM classifier
clf = SVC(kernel='linear', random_state=600)
clf.fit(X_train_vect, y3_train)
# Out:
# SVC(kernel='linear', random_state=600)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.7387387387387387
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.99      0.83        74
#            1       0.90      0.24      0.38        37
#
#     accuracy                           0.74       111
#    macro avg       0.81      0.61      0.61       111
# weighted avg       0.78      0.74      0.68       111

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
