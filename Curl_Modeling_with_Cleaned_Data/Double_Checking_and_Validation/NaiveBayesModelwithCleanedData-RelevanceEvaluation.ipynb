# %% [markdown]
# # Modeling with Naive Bayes

# %% [markdown]
# #### We build multiple Naive Bayes Models to Train on cleaned text and variables:
# #### Relevancy_score (highly relevant (4), very relevant (3), relevant (2), minimally relevant (1), not relevant (0))
# #### Treatment_Number (user receives treatment (1), user does not receive treatment (0))
# #### Recommendation_Score (user recommends treatment (1), user does not recommend treatment (0))

# %%
#import the necessary library, modules, functions, settings 
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
from seaborn import set_style
set_style("whitegrid")
import seaborn as sns

# %%
#load in the csv file containing the relevance validation set as a data frame 
data_df = pd.read_csv("FinalEvaluatedRelevanceValidation.csv")

# %%
#import the necessary library, modules, functions, settings 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,  classification_report
from sklearn.model_selection import train_test_split
from collections import defaultdict
from imblearn.over_sampling import SMOTE

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=100, test_size=0.2)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_vect, y1_train)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y1_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.7901234567901234
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        28
#            1       0.00      0.00      0.00        11
#            2       0.82      1.00      0.90        40
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.79        81
#    macro avg       0.31      0.37      0.34        81
# weighted avg       0.66      0.79      0.72        81
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=200, test_size=0.2,stratify=y2)
X_train_vect = vectorizer1.fit_transform(X_train)
sm = SMOTE(sampling_strategy='auto', k_neighbors=2)
X_train_res, y2_train_res = sm.fit_resample(X_train_vect, y2_train)

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_res, y2_train_res)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y2_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.7901234567901234
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.58      0.69        33
#            1       0.76      0.94      0.84        48
#
#     accuracy                           0.79        81
#    macro avg       0.81      0.76      0.77        81
# weighted avg       0.80      0.79      0.78        81

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=300, test_size=0.2,stratify=y3)
X_train_vect = vectorizer1.fit_transform(X_train)
sm = SMOTE(sampling_strategy='auto', k_neighbors=2)
X_train_res, y3_train_res = sm.fit_resample(X_train_vect, y3_train)

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_res, y3_train_res)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y3_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.7160493827160493
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82        66
#            1       0.30      0.40      0.34        15
#
#     accuracy                           0.72        81
#    macro avg       0.58      0.59      0.58        81
# weighted avg       0.75      0.72      0.73        81

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=400, test_size=0.2)
X_train_vect = vectorizer2.fit_transform(X_train)
#we can't perform stratify or any special splitting of the data becuase most is marked relevant

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_vect, y1_train)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y1_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.7283950617283951
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83        39
#            1       0.00      0.00      0.00         8
#            2       0.62      0.97      0.76        29
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.73        81
#    macro avg       0.37      0.44      0.40        81
# weighted avg       0.64      0.73      0.67        81
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/envs/erdos_may_2024_v2/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=500, test_size=0.2,stratify=y2)
X_train_vect = vectorizer2.fit_transform(X_train)
sm = SMOTE(sampling_strategy='auto', k_neighbors=2)
X_train_res, y2_train_res = sm.fit_resample(X_train_vect, y2_train)

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_res, y2_train_res)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y2_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.7901234567901234
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.67      0.72        33
#            1       0.79      0.88      0.83        48
#
#     accuracy                           0.79        81
#    macro avg       0.79      0.77      0.78        81
# weighted avg       0.79      0.79      0.79        81

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=600, test_size=0.2,stratify=y3)
X_train_vect = vectorizer2.fit_transform(X_train)
sm = SMOTE(sampling_strategy='auto', k_neighbors=2)
X_train_res, y3_train_res = sm.fit_resample(X_train_vect, y3_train)

# %%
#Initialize and train an instance of Naive Bayes Classifier 
nb = MultinomialNB()
nb.fit(X_train_res, y3_train_res)
# Out:
# MultinomialNB()

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y3_pred = nb.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.35802469135802467
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.23      0.37        66
#            1       0.22      0.93      0.35        15
#
#     accuracy                           0.36        81
#    macro avg       0.58      0.58      0.36        81
# weighted avg       0.80      0.36      0.36        81

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
