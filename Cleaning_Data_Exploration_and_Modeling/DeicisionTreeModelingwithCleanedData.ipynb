# %% [markdown]
# # Modeling with Decision Tree Classifer

# %% [markdown]
# #### We build multiple Decision Tree Classifer Models to Train on cleaned text and variables:
# #### Relevancy_score (highly relevant (4), very relevant (3), relevant (2), minimally relevant (1), not relevant (0))
# #### Treatment_Number (user receives treatment (1), user does not receive treatment (0))
# #### Recommendation_Score (user recommends treatment (1), user does not recommend treatment (0))

# %%
#import the necessary library, modules, functions, settings 
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
from seaborn import set_style
set_style("whitegrid")
import seaborn as sns

# %%
#load in the csv file containing the cleaned and formatted Reddit content as a data frame 
data_df = pd.read_csv("enumerated_suicidebpd_comments.csv")

# %%
#import the necessary library, modules, functions, settings 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,  classification_report
from sklearn.model_selection import train_test_split

# %%
#vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=100, test_size=0.2, stratify=y1)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train_vect, y1_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.6694214876033058
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78        77
#            1       0.51      0.55      0.53        33
#            2       0.30      0.38      0.33         8
#            3       1.00      0.33      0.50         3
#
#     accuracy                           0.67       121
#    macro avg       0.65      0.51      0.53       121
# weighted avg       0.69      0.67      0.67       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=200, test_size=0.2,stratify=y2)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=200)
clf.fit(X_train_vect, y2_train)
# Out:
# DecisionTreeClassifier(random_state=200)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y2_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("precision:", precision_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.8925619834710744
# precision: 0.375
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       110
#            1       0.38      0.27      0.32        11
#
#     accuracy                           0.89       121
#    macro avg       0.65      0.61      0.63       121
# weighted avg       0.88      0.89      0.88       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer1 = CountVectorizer()
vectors = vectorizer1.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=300, test_size=0.2,stratify=y3)
X_train_vect = vectorizer1.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=300)
clf.fit(X_train_vect, y3_train)
# Out:
# DecisionTreeClassifier(random_state=300)

# %%
# Make predictions
X_test_vect = vectorizer1.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.9586776859504132
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       117
#            1       0.43      0.75      0.55         4
#
#     accuracy                           0.96       121
#    macro avg       0.71      0.86      0.76       121
# weighted avg       0.97      0.96      0.96       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y1 = data_df.Relevancy_Score
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, random_state=400, test_size=0.2,stratify=y1)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=400)
clf.fit(X_train_vect, y1_train)
# Out:
# DecisionTreeClassifier(random_state=400)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y1_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y1_test, y1_pred))
print("\nClassification Report:\n", classification_report(y1_test, y1_pred))
# Out:
# Accuracy: 0.6198347107438017
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.74      0.78        77
#            1       0.37      0.48      0.42        33
#            2       0.17      0.12      0.14         8
#            3       0.50      0.33      0.40         3
#
#     accuracy                           0.62       121
#    macro avg       0.46      0.42      0.43       121
# weighted avg       0.64      0.62      0.63       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y1_test, y1_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y2 = data_df.Treatment_Number
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, random_state=500, test_size=0.2,stratify=y2)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=500)
clf.fit(X_train_vect, y2_train)
# Out:
# DecisionTreeClassifier(random_state=500)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y2_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print("\nClassification Report:\n", classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.8842975206611571
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       110
#            1       0.33      0.27      0.30        11
#
#     accuracy                           0.88       121
#    macro avg       0.63      0.61      0.62       121
# weighted avg       0.87      0.88      0.88       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y2_test, y2_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Vectorize text and create a train test split 
vectorizer2 = TfidfVectorizer()
vectors = vectorizer2.fit_transform(data_df.Comment)
X = data_df.Comment
y3 = data_df.Recommendation_Score
X_train, X_test, y3_train, y3_test = train_test_split(X, y3, random_state=600, test_size=0.2,stratify=y3)
X_train_vect = vectorizer2.fit_transform(X_train)

# %%
#Initialize and train an instance of Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=600)
clf.fit(X_train_vect, y3_train)
# Out:
# DecisionTreeClassifier(random_state=600)

# %%
# Make predictions
X_test_vect = vectorizer2.transform(X_test)
y3_pred = clf.predict(X_test_vect)

# %%
# Evaluate the model
print("Accuracy:", accuracy_score(y3_test, y3_pred))
print("\nClassification Report:\n", classification_report(y3_test, y3_pred))
# Out:
# Accuracy: 0.9669421487603306
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       117
#            1       0.50      0.25      0.33         4
#
#     accuracy                           0.97       121
#    macro avg       0.74      0.62      0.66       121
# weighted avg       0.96      0.97      0.96       121

# %%
#Produce the confusion matrix 
cm = confusion_matrix(y3_test, y3_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
